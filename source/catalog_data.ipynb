# %%
# %sql
CREATE CATALOG IF NOT EXISTS source;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS bronze;

# %%
# %sql
CREATE TABLE IF NOT EXISTS source.default.orders (
    id INT,
    category STRING,
    amount INT,
    ingestion_date TIMESTAMP
)
USING DELTA;

# %%
# %sql
INSERT INTO source.default.orders VALUES
(1, 'A', 100, TIMESTAMP('2025-12-11 10:00:00')),
(2, 'B', 200, TIMESTAMP('2025-12-11 10:00:00')),
(3, 'A', 150, TIMESTAMP('2025-12-11 10:00:00')),
(4, 'C', 300, TIMESTAMP('2025-12-11 10:00:00')),
(5, 'B',  50, TIMESTAMP('2025-12-11 10:00:00'));

# %%
# %sql
SELECT * FROM source.default.orders;

# %%
# %sql
desc source.default.orders
